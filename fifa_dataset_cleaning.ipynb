# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Accessment of Data

# %%
# Making the copy of the dataset 

df_fifa = pd.read_csv('Fifa_world_cup3.csv')
fifa = df_fifa.copy()

# %% [markdown]
# ### Data Summery
#
# - The dataset represents historical information on FIFA World Cup matches. It includes details about home and away teams, match scores, penalties, goals, and other match-specific data like the stadium, city, attendance, and referee information. There are 865 matches in the dataset, and certain columns contain incomplete data, especially for goals scored by the first and second teams, and referee cities. Some columns, such as attendance, contain non-numeric values, and date formatting is inconsistent.

# %% [markdown]
# ### Info About Each Column
#
# - __Home_Team:__ The name of the home team (object type).
# - __Score:__ The match score (object type).
# - __Away_Team:__ The name of the away team (object type).
# - __Penalties:__ Indicates whether penalties were involved (object type).
# - __First_Team_Goals:__ Descriptions of goals scored by the first team (object type).
# - __Second_Team_Goals:__ Descriptions of goals scored by the second team (object type).
# - __Date:__ Date of the match (object type).
# - __Time:__ Time of the match (object type).
# - __Stadium:__ Stadium where the match was played (object type).
# - __City:__ City where the match was played (object type).
# - __Attendance:__ The number of spectators (object type).
# - __Referee:__ The referee of the match (object type).
# - __Referee_City:__ The city where the referee is from (object type).

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Home_Team          929 non-null    object
#  1   Score              929 non-null    object
#  2   Away_Team          929 non-null    object
#  3   Penalties          929 non-null    object
#  4   First_Team_Goals   722 non-null    object
#  5   Second_Team_Goals  602 non-null    object
#  6   Date               929 non-null    object
#  7   Time               928 non-null    object
#  8   Stadium            929 non-null    object
#  9   City               907 non-null    object
#  10  Attendance         928 non-null    object
#  11  Referee            928 non-null    object
#  12  Referee_City       887 non-null    object
# dtypes: object(13)
# memory usage: 94.5+ KB

# %%
fifa.describe()
# Out:
#        Home_Team Score Away_Team Penalties First_Team_Goals  \
# count        929   929       929       929              722
# unique        81    69        87        14              721
# top      Brazil    1–0    Mexico        NO    Houseman  20'
# freq          82   100        41       894                2
#
#                         Second_Team_Goals         Date   Time         Stadium  \
# count                                 602          929    928             929
# unique                                602          365    125             209
# top     Mbappé 80' (pen.) 81' 118' (pen.)  27 May 1934  16:00  Estadio Azteca
# freq                                    1            8     80              19
#
#                City          Attendance          Referee Referee_City
# count           907                 928              928          887
# unique          169                 720              410           88
# top     Mexico City  Attendance: 45,000  Ravshan Irmatov        Italy
# freq             23                  13               11           51

# %%
fifa[fifa['Time'].isnull()]
# Out:
#    Home_Team Score Away_Team Penalties First_Team_Goals Second_Team_Goals  \
# 37   Sweden    w/o   Austria        NO              NaN               NaN
#
#            Date Time        Stadium  City Attendance Referee Referee_City
# 37  5 June 1938  NaN  Stade Gerland  Lyon        NaN     NaN          NaN

# %%
fifa['First_Team_Goals'].isnull().sum()
# Out:
# np.int64(207)

# %%
fifa['Second_Team_Goals'].isnull().sum()
# Out:
# np.int64(327)

# %%
fifa.head()
# Out:
#     Home_Team Score Away_Team Penalties  \
# 0     France    4–1    Mexico        NO
# 1  Argentina    1–0    France        NO
# 2      Chile    3–0    Mexico        NO
# 3      Chile    1–0    France        NO
# 4  Argentina    6–3    Mexico        NO
#
#                                     First_Team_Goals  \
# 0  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                         Monti  81'
# 2         Vidal  3', 65'; M. Rosas  52' (o.g.); o.g.
# 3                                      Subiabre  67'
# 4  Stábile  8', 17', 80'; Zumelzú  12', 55'; Vara...
#
#                              Second_Team_Goals          Date  \
# 0                                 Carreño  70'  13 July 1930
# 1                                          NaN  15 July 1930
# 2                                          NaN  16 July 1930
# 3                                          NaN  19 July 1930
# 4  M. Rosas  42' (pen.), 65'; pen.  75'; Gayón  19 July 1930
#
#                     Time                 Stadium        City  \
# 0  15:00 UYT (UTC−03:30)         Estadio Pocitos  Montevideo
# 1  16:00 UYT (UTC−03:30)  Estadio Parque Central  Montevideo
# 2  14:45 UYT (UTC−03:30)  Estadio Parque Central  Montevideo
# 3  12:50 UYT (UTC−03:30)      Estadio Centenario  Montevideo
# 4  15:00 UYT (UTC−03:30)      Estadio Centenario  Montevideo
#
#            Attendance           Referee Referee_City
# 0   Attendance: 4,444           Uruguay          NaN
# 1  Attendance: 23,409      Almeida Rêgo       Brazil
# 2   Attendance: 9,249  Henri Christophe      Belgium
# 3   Attendance: 2,000           Uruguay          NaN
# 4  Attendance: 42,100    Ulises Saucedo      Bolivia

# %%
fifa.tail()
# Out:
#       Home_Team         Score Away_Team Penalties  \
# 924    England            1–2    France        NO
# 925  Argentina            3–0   Croatia        NO
# 926     France            2–0   Morocco        NO
# 927    Croatia            2–1   Morocco        NO
# 928  Argentina   3–3 (a.e.t.)    France       4–2
#
#                         First_Team_Goals                  Second_Team_Goals  \
# 924                      Kane 54' (pen.)         Tchouaméni 17'; Giroud 78'
# 925    Messi 34' (pen.); Álvarez 39' 69'                                NaN
# 926      T. Hernandez 5'; Kolo Muani 79'                                NaN
# 927               Gvardiol 7'; Oršić 42'                            Dari 9'
# 928  Messi 23' (pen.) 108'; Di María 36'  Mbappé 80' (pen.) 81' 118' (pen.)
#
#                               Date   Time                        Stadium  \
# 924  10 December 2022 (2022-12-10)  22:00                Al Bayt Stadium
# 925  13 December 2022 (2022-12-13)  22:00                 Lusail Stadium
# 926  14 December 2022 (2022-12-14)  22:00                Al Bayt Stadium
# 927  17 December 2022 (2022-12-17)  18:00  Khalifa International Stadium
# 928  18 December 2022 (2022-12-18)  18:00                 Lusail Stadium
#
#           City          Attendance                Referee Referee_City
# 924    Al Khor  Attendance: 68,895         Wilton Sampaio       Brazil
# 925     Lusail  Attendance: 88,966         Daniele Orsato        Italy
# 926    Al Khor  Attendance: 68,294     César Arturo Ramos       Mexico
# 927  Al Rayyan  Attendance: 44,137  Abdulrahman Al-Jassim        Qatar
# 928     Lusail  Attendance: 88,966       Szymon Marciniak       Poland

# %%
fifa.sample(5)
# Out:
#       Home_Team Score      Away_Team Penalties  \
# 310       Peru    0–0       Cameroon        NO
# 804    Uruguay    1–0   Saudi Arabia        NO
# 570    Germany    8–0   Saudi Arabia        NO
# 243   Scotland    1–1     Yugoslavia        NO
# 366  Argentina    2–0       Bulgaria        NO
#
#                                       First_Team_Goals Second_Team_Goals  \
# 310                                                NaN               NaN
# 804                                         Suárez 23'               NaN
# 570  Klose  20', 25', 70'; Ballack  40'; Jancker  4...               NaN
# 243                                        Jordan  88'       Karasi  81'
# 366                       Valdano  4'; Burruchaga  77'               NaN
#
#                           Date               Time  \
# 310               15 June 1982         17:15 CEST
# 804  20 June 2018 (2018-06-20)  18:00 MSK (UTC+3)
# 570                1 June 2002  20:30 JST (UTC+9)
# 243               22 June 1974              16:00
# 366               10 June 1986          12:00 CST
#
#                             Stadium           City               Attendance  \
# 310               Estadio de Riazor       A Coruña       Attendance: 11,000
# 804                    Rostov Arena  Rostov-on-Don  Attendance: 42,678[146]
# 570                    Sapporo Dome        Sapporo       Attendance: 32,218
# 243                     Waldstadion      Frankfurt       Attendance: 56,000
# 366  Estadio Olímpico Universitario    Mexico City       Attendance: 65,000
#
#                         Referee Referee_City
# 310                Franz Wöhrer      Austria
# 804              Clément Turpin       France
# 570               Ubaldo Aquino     Paraguay
# 243  Alfonso González Archundía       Mexico
# 366          Berny Ulloa Morera   Costa Rica

# %% [markdown]
# ### Dirty Data vs Messy Data

# %% [markdown]
# #### Dirty Data
#
# - Home_Team
#     1. Need to strip the spaces in the name __Consistency__
#     2. Need to change all the letter into smaller cases __Consistency__
#
# - Attendance
#     1. The values contain non-numeric characters (e.g., "Attendance: 4,444").
#         __Validity__
#
# - First_Team_Goals & Second_Team_Goals
#     1. The format includes textual representations of goals, such as "L. Laurent 19'" and mixed data types. __Accuracy__
#
# - Date
#     1. Inconsistent formats like "8 June 1958" and "15 July 1930". Need to remove one of the date.__Consistency__
#     2. Also need to change the type to datetime. __Accuracy__
#
# - Referee_City
#     1. Missing data in several rows.
#        __Completeness__
#
# - Penalties
#     1. There are only two values: "YES" and "NO". It can be simplified to binary (1 or 0). __Consistency__
#
# - Score
#     1. The scores are represented in a non-standardized format, e.g., "4–1". __Consistency__
#     2. Need to change the type to int __Validity__
#
# - Time
#     1. Need to remove extra written text. __Validity__
#     2. Need to change the column type datetime __Consistency__
#
# #### Messy Data
#
# - First_Team_Goal
#     1. Need to make one more column in which it will show the player name who goal and at what time for Home team
#
# - Second_Team_Goal
#     1. Need to make one more column in which it will show the player name who goal and at what time for away team
#
# - Score
#     1. Need to make the two different row. One for Home teams score and away teams score team. Then one more for the winner team.

# %% [markdown]
# ### Define, code, test

# %%
# Home_Team: Strip spaces and convert to lowercase
fifa['Home_Team'] = fifa['Home_Team'].str.strip().str.lower()

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Home_Team          929 non-null    object
#  1   Score              929 non-null    object
#  2   Away_Team          929 non-null    object
#  3   Penalties          929 non-null    object
#  4   First_Team_Goals   722 non-null    object
#  5   Second_Team_Goals  602 non-null    object
#  6   Date               929 non-null    object
#  7   Time               928 non-null    object
#  8   Stadium            929 non-null    object
#  9   City               907 non-null    object
#  10  Attendance         928 non-null    object
#  11  Referee            928 non-null    object
#  12  Referee_City       887 non-null    object
# dtypes: object(13)
# memory usage: 94.5+ KB

# %%
fifa['First_Team_Goals'].fillna(0, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20740\1134096415.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fifa['First_Team_Goals'].fillna(0, inplace=True)

# %%
fifa['Second_Team_Goals'].fillna(0, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20740\2102830755.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fifa['Second_Team_Goals'].fillna(0, inplace=True)

# %%
fifa['City'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20740\703393346.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fifa['City'].fillna('Unknown', inplace=True)

# %%
fifa['Referee_City'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20740\3027417422.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fifa['Referee_City'].fillna('Unknown', inplace=True)

# %%
fifa.head()
# Out:
#    Home_Team Score Away_Team Penalties  \
# 0     france   4–1    Mexico        NO
# 1  argentina   1–0    France        NO
# 2      chile   3–0    Mexico        NO
# 3      chile   1–0    France        NO
# 4  argentina   6–3    Mexico        NO
#
#                                     First_Team_Goals  \
# 0  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                         Monti  81'
# 2         Vidal  3', 65'; M. Rosas  52' (o.g.); o.g.
# 3                                      Subiabre  67'
# 4  Stábile  8', 17', 80'; Zumelzú  12', 55'; Vara...
#
#                              Second_Team_Goals          Date  \
# 0                                 Carreño  70'  13 July 1930
# 1                                            0  15 July 1930
# 2                                            0  16 July 1930
# 3                                            0  19 July 1930
# 4  M. Rosas  42' (pen.), 65'; pen.  75'; Gayón  19 July 1930
#
#                     Time                 Stadium        City  \
# 0  15:00 UYT (UTC−03:30)         Estadio Pocitos  Montevideo
# 1  16:00 UYT (UTC−03:30)  Estadio Parque Central  Montevideo
# 2  14:45 UYT (UTC−03:30)  Estadio Parque Central  Montevideo
# 3  12:50 UYT (UTC−03:30)      Estadio Centenario  Montevideo
# 4  15:00 UYT (UTC−03:30)      Estadio Centenario  Montevideo
#
#            Attendance           Referee Referee_City
# 0   Attendance: 4,444           Uruguay      Unknown
# 1  Attendance: 23,409      Almeida Rêgo       Brazil
# 2   Attendance: 9,249  Henri Christophe      Belgium
# 3   Attendance: 2,000           Uruguay      Unknown
# 4  Attendance: 42,100    Ulises Saucedo      Bolivia

# %%
import re
def clean_attendance(value):
    if pd.isnull(value):  # Check for null values to avoid processing them
        return None
    numeric_value = re.sub(r'[^0-9]', '', str(value))
    return int(numeric_value) if numeric_value else None

fifa['Attendance'] = fifa['Attendance'].apply(clean_attendance)

# %%
fifa.head()
# Out:
#    Home_Team Score Away_Team Penalties  \
# 0     france   4–1    Mexico        NO
# 1  argentina   1–0    France        NO
# 2      chile   3–0    Mexico        NO
# 3      chile   1–0    France        NO
# 4  argentina   6–3    Mexico        NO
#
#                                     First_Team_Goals  \
# 0  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                         Monti  81'
# 2         Vidal  3', 65'; M. Rosas  52' (o.g.); o.g.
# 3                                      Subiabre  67'
# 4  Stábile  8', 17', 80'; Zumelzú  12', 55'; Vara...
#
#                              Second_Team_Goals          Date  \
# 0                                 Carreño  70'  13 July 1930
# 1                                            0  15 July 1930
# 2                                            0  16 July 1930
# 3                                            0  19 July 1930
# 4  M. Rosas  42' (pen.), 65'; pen.  75'; Gayón  19 July 1930
#
#                     Time                 Stadium        City  Attendance  \
# 0  15:00 UYT (UTC−03:30)         Estadio Pocitos  Montevideo      4444.0
# 1  16:00 UYT (UTC−03:30)  Estadio Parque Central  Montevideo     23409.0
# 2  14:45 UYT (UTC−03:30)  Estadio Parque Central  Montevideo      9249.0
# 3  12:50 UYT (UTC−03:30)      Estadio Centenario  Montevideo      2000.0
# 4  15:00 UYT (UTC−03:30)      Estadio Centenario  Montevideo     42100.0
#
#             Referee Referee_City
# 0           Uruguay      Unknown
# 1      Almeida Rêgo       Brazil
# 2  Henri Christophe      Belgium
# 3           Uruguay      Unknown
# 4    Ulises Saucedo      Bolivia

# %%
import re

# Function to clean attendance values by removing non-numeric characters
def clean_attendance(value):
    numeric_value = re.sub(r'[^0-9]', '', str(value))
    return int(numeric_value) if numeric_value else None

fifa['Attendance'] = fifa['Attendance'].apply(clean_attendance)

# %%
fifa.head()
# Out:
#    Home_Team Score Away_Team Penalties  \
# 0     france   4–1    Mexico        NO
# 1  argentina   1–0    France        NO
# 2      chile   3–0    Mexico        NO
# 3      chile   1–0    France        NO
# 4  argentina   6–3    Mexico        NO
#
#                                     First_Team_Goals  \
# 0  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                         Monti  81'
# 2         Vidal  3', 65'; M. Rosas  52' (o.g.); o.g.
# 3                                      Subiabre  67'
# 4  Stábile  8', 17', 80'; Zumelzú  12', 55'; Vara...
#
#                              Second_Team_Goals          Date  \
# 0                                 Carreño  70'  13 July 1930
# 1                                            0  15 July 1930
# 2                                            0  16 July 1930
# 3                                            0  19 July 1930
# 4  M. Rosas  42' (pen.), 65'; pen.  75'; Gayón  19 July 1930
#
#                     Time                 Stadium        City  Attendance  \
# 0  15:00 UYT (UTC−03:30)         Estadio Pocitos  Montevideo     44440.0
# 1  16:00 UYT (UTC−03:30)  Estadio Parque Central  Montevideo    234090.0
# 2  14:45 UYT (UTC−03:30)  Estadio Parque Central  Montevideo     92490.0
# 3  12:50 UYT (UTC−03:30)      Estadio Centenario  Montevideo     20000.0
# 4  15:00 UYT (UTC−03:30)      Estadio Centenario  Montevideo    421000.0
#
#             Referee Referee_City
# 0           Uruguay      Unknown
# 1      Almeida Rêgo       Brazil
# 2  Henri Christophe      Belgium
# 3           Uruguay      Unknown
# 4    Ulises Saucedo      Bolivia

# %%
fifa['Date'] = fifa['Date'].str.strip().str.split("(" ).str.get(0)

# %%
fifa['Date'] = pd.DatetimeIndex(fifa['Date'])

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Home_Team          929 non-null    object
#  1   Score              929 non-null    object
#  2   Away_Team          929 non-null    object
#  3   Penalties          929 non-null    object
#  4   First_Team_Goals   929 non-null    object
#  5   Second_Team_Goals  929 non-null    object
#  6   Date               929 non-null    datetime64[ns]
#  7   Time               928 non-null    object
#  8   Stadium            929 non-null    object
#  9   City               929 non-null    object
#  10  Attendance         928 non-null    float64
#  11  Referee            928 non-null    object
#  12  Referee_City       929 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(11)
# memory usage: 94.5+ KB

# %%
# Penalties: Simplify "YES" and "NO" to binary values (1 for YES, 0 for NO)
fifa['Penalties'] = fifa['Penalties'].apply(lambda x: 1 if x == 'YES' else 0)

# %%
fifa.head()
# Out:
#    Home_Team Score Away_Team  Penalties  \
# 0     france   4–1    Mexico          0
# 1  argentina   1–0    France          0
# 2      chile   3–0    Mexico          0
# 3      chile   1–0    France          0
# 4  argentina   6–3    Mexico          0
#
#                                     First_Team_Goals  \
# 0  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                         Monti  81'
# 2         Vidal  3', 65'; M. Rosas  52' (o.g.); o.g.
# 3                                      Subiabre  67'
# 4  Stábile  8', 17', 80'; Zumelzú  12', 55'; Vara...
#
#                              Second_Team_Goals       Date  \
# 0                                 Carreño  70' 1930-07-13
# 1                                            0 1930-07-15
# 2                                            0 1930-07-16
# 3                                            0 1930-07-19
# 4  M. Rosas  42' (pen.), 65'; pen.  75'; Gayón 1930-07-19
#
#                     Time                 Stadium        City  Attendance  \
# 0  15:00 UYT (UTC−03:30)         Estadio Pocitos  Montevideo     44440.0
# 1  16:00 UYT (UTC−03:30)  Estadio Parque Central  Montevideo    234090.0
# 2  14:45 UYT (UTC−03:30)  Estadio Parque Central  Montevideo     92490.0
# 3  12:50 UYT (UTC−03:30)      Estadio Centenario  Montevideo     20000.0
# 4  15:00 UYT (UTC−03:30)      Estadio Centenario  Montevideo    421000.0
#
#             Referee Referee_City
# 0           Uruguay      Unknown
# 1      Almeida Rêgo       Brazil
# 2  Henri Christophe      Belgium
# 3           Uruguay      Unknown
# 4    Ulises Saucedo      Bolivia

# %%
fifa['Time'] = fifa['Time'].astype('string')

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Home_Team          929 non-null    object
#  1   Score              929 non-null    object
#  2   Away_Team          929 non-null    object
#  3   Penalties          929 non-null    int64
#  4   First_Team_Goals   929 non-null    object
#  5   Second_Team_Goals  929 non-null    object
#  6   Date               929 non-null    datetime64[ns]
#  7   Time               928 non-null    string
#  8   Stadium            929 non-null    object
#  9   City               929 non-null    object
#  10  Attendance         928 non-null    float64
#  11  Referee            928 non-null    object
#  12  Referee_City       929 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9), string(1)
# memory usage: 94.5+ KB

# %%
fifa['Time'].astype('string')
# Out:
# 0      15:00 UYT (UTC−03:30)
# 1      16:00 UYT (UTC−03:30)
# 2      14:45 UYT (UTC−03:30)
# 3      12:50 UYT (UTC−03:30)
# 4      15:00 UYT (UTC−03:30)
#                ...
# 924                    22:00
# 925                    22:00
# 926                    22:00
# 927                    18:00
# 928                    18:00
# Name: Time, Length: 929, dtype: string

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Home_Team          929 non-null    object
#  1   Score              929 non-null    object
#  2   Away_Team          929 non-null    object
#  3   Penalties          929 non-null    int64
#  4   First_Team_Goals   929 non-null    object
#  5   Second_Team_Goals  929 non-null    object
#  6   Date               929 non-null    datetime64[ns]
#  7   Time               928 non-null    string
#  8   Stadium            929 non-null    object
#  9   City               929 non-null    object
#  10  Attendance         928 non-null    float64
#  11  Referee            928 non-null    object
#  12  Referee_City       929 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9), string(1)
# memory usage: 94.5+ KB

# %%
fifa['Time'] = fifa['Time'].str.split(" ").str.get(0)

# %%
def clean_time(value):
    if pd.isnull(value):  
        return np.nan
   
    time_part = value.split(' ')[0]
    return time_part 

fifa['Start_Time'] = fifa['Time'].apply(clean_time)

fifa['Start_Time'] = pd.to_datetime(fifa['Start_Time'], format='%H:%M', errors='coerce').dt.time

# %%
fifa['Time'] = fifa['Start_Time']

# %%
fifa.drop(columns=['Start_Time','Cleaned_Time' ], inplace=True)

# %%
fifa.head()
# Out:
#    Home_Team Score Away_Team  Penalties  \
# 0     france   4–1    Mexico          0
# 1  argentina   1–0    France          0
# 2      chile   3–0    Mexico          0
# 3      chile   1–0    France          0
# 4  argentina   6–3    Mexico          0
#
#                                     First_Team_Goals  \
# 0  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                         Monti  81'
# 2         Vidal  3', 65'; M. Rosas  52' (o.g.); o.g.
# 3                                      Subiabre  67'
# 4  Stábile  8', 17', 80'; Zumelzú  12', 55'; Vara...
#
#                              Second_Team_Goals       Date      Time  \
# 0                                 Carreño  70' 1930-07-13  15:00:00
# 1                                            0 1930-07-15  16:00:00
# 2                                            0 1930-07-16  14:45:00
# 3                                            0 1930-07-19  12:50:00
# 4  M. Rosas  42' (pen.), 65'; pen.  75'; Gayón 1930-07-19  15:00:00
#
#                   Stadium        City  Attendance           Referee  \
# 0         Estadio Pocitos  Montevideo     44440.0           Uruguay
# 1  Estadio Parque Central  Montevideo    234090.0      Almeida Rêgo
# 2  Estadio Parque Central  Montevideo     92490.0  Henri Christophe
# 3      Estadio Centenario  Montevideo     20000.0           Uruguay
# 4      Estadio Centenario  Montevideo    421000.0    Ulises Saucedo
#
#   Referee_City
# 0      Unknown
# 1       Brazil
# 2      Belgium
# 3      Unknown
# 4      Bolivia

# %%
def extract_goals(goal_column):
    player_names = []
    goal_times = []
    for goals in goal_column:
        if pd.isna(goals):
            continue
        goal_entries = re.split(r'; |, ', goals)
        for entry in goal_entries:
            match = re.match(r'(.+?)\s(\d+)\'', entry)
            if match:
                player_names.append(match.group(1).strip())
                goal_times.append(match.group(2).strip())
    return player_names, goal_times

expanded_rows = []

for index, row in fifa.iterrows():
    first_team_players, first_team_times = extract_goals([row['First_Team_Goals']])
    second_team_players, second_team_times = extract_goals([row['Second_Team_Goals']])
    
    all_players = first_team_players + second_team_players
    all_goal_times = first_team_times + second_team_times
    
    for player, goal_time in zip(all_players, all_goal_times):
        new_row = row.copy()
        new_row['Player_Name'] = player
        new_row['Goal_Time'] = goal_time
        expanded_rows.append(new_row)

expanded_fifa = pd.DataFrame(expanded_rows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 19
#      17 for index, row in fifa.iterrows():
#      18     first_team_players, first_team_times = extract_goals([row['First_Team_Goals']])
# ---> 19     second_team_players, second_team_times = extract_goals([row['Second_Team_Goals']])
#      21     all_players = first_team_players + second_team_players
#      22     all_goal_times = first_team_times + second_team_times
#
# Cell In[178], line 7, in extract_goals(goal_column)
#       5 if pd.isna(goals):
#       6     continue
# ----> 7 goal_entries = re.split(r'; |, ', goals)
#       8 for entry in goal_entries:
#       9     match = re.match(r'(.+?)\s(\d+)\'', entry)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:207, in split(pattern, string, maxsplit, flags)
#     199 def split(pattern, string, maxsplit=0, flags=0):
#     200     """Split the source string by the occurrences of the pattern,
#     201     returning a list containing the resulting substrings.  If
#     202     capturing parentheses are used in pattern, then the text of all
#    (...)
#     205     and the remainder of the string is returned as the final element
#     206     of the list."""
# --> 207     return _compile(pattern, flags).split(string, maxsplit)
#
# TypeError: expected string or bytes-like object, got 'int'

# %%
expanded_fifa
# Out:
#      Home_Team Score Away_Team  Penalties  \
# 0       france   4–1    Mexico          0
# 0       france   4–1    Mexico          0
# 0       france   4–1    Mexico          0
# 0       france   4–1    Mexico          0
# 1    argentina   1–0    France          0
# ..         ...   ...       ...        ...
# 864     france   4–2   Croatia          0
# 864     france   4–2   Croatia          0
# 864     france   4–2   Croatia          0
# 864     france   4–2   Croatia          0
# 864     france   4–2   Croatia          0
#
#                                       First_Team_Goals  \
# 0    L. Laurent  19'; Langiller  40'; Maschinot  43...
# 0    L. Laurent  19'; Langiller  40'; Maschinot  43...
# 0    L. Laurent  19'; Langiller  40'; Maschinot  43...
# 0    L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1                                           Monti  81'
# ..                                                 ...
# 864  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
#
#               Second_Team_Goals       Date            Time  \
# 0                  Carreño  70' 1930-07-13 0 days 15:00:00
# 0                  Carreño  70' 1930-07-13 0 days 15:00:00
# 0                  Carreño  70' 1930-07-13 0 days 15:00:00
# 0                  Carreño  70' 1930-07-13 0 days 15:00:00
# 1                           NaN 1930-07-15 0 days 16:00:00
# ..                          ...        ...             ...
# 864  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 864  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 864  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 864  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 864  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
#
#                     Stadium        City  Attendance        Referee  \
# 0           Estadio Pocitos  Montevideo     44440.0        Uruguay
# 0           Estadio Pocitos  Montevideo     44440.0        Uruguay
# 0           Estadio Pocitos  Montevideo     44440.0        Uruguay
# 0           Estadio Pocitos  Montevideo     44440.0        Uruguay
# 1    Estadio Parque Central  Montevideo    234090.0   Almeida Rêgo
# ..                      ...         ...         ...            ...
# 864        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 864        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 864        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 864        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 864        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
#
#     Referee_City                                       Players_Goal  \
# 0            NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 0            NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 0            NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 0            NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1         Brazil                                                NaN
# ..           ...                                                ...
# 864    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 864    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
#
#     Player_Name Goal_Time
# 0    L. Laurent        19
# 0     Langiller        40
# 0     Maschinot        43
# 0       Carreño        70
# 1         Monti        81
# ..          ...       ...
# 864   Griezmann        38
# 864       Pogba        59
# 864      Mbappé        65
# 864     Perišić        28
# 864   Mandžukić        69
#
# [2032 rows x 16 columns]

# %%
expanded_fifa.sort_values([])
# Out:
#         Home_Team         Score        Away_Team  Penalties  \
# 158       hungary           6–1         Bulgaria          0
# 327       england           3–1           France          0
# 607   south korea           2–3           Turkey          0
# 33        germany           3–2          Austria          0
# 774         ghana           1–2    United States          0
# ..            ...           ...              ...        ...
# 34          italy  2–1 (a.e.t.)   Czechoslovakia          0
# 230         italy  4–3 (a.e.t.)     West Germany          0
# 358  west germany  3–3 (a.e.t.)           France          0
# 658     argentina  2–1 (a.e.t.)           Mexico          0
# 230         italy  4–3 (a.e.t.)     West Germany          0
#
#                                       First_Team_Goals  \
# 158  Albert  1', 6', 53'; Tichy  8', 70'; Solymosi ...
# 327                      Robson  1', 67'; Mariner  83'
# 607            Lee Eul-yong  9'; Song Chong-gug  90+3'
# 33                         Lehner  1', 42'; Conen  27'
# 774                                        A. Ayew 82'
# ..                                                 ...
# 34                            Orsi  81'; Schiavio  95'
# 230  Boninsegna  8'; Burgnich  98'; Riva  104'; Riv...
# 358   Littbarski  17'; Rummenigge  102'; Fischer  108'
# 658                          Crespo 10'; Rodríguez 98'
# 230  Boninsegna  8'; Burgnich  98'; Riva  104'; Riv...
#
#                                      Second_Team_Goals       Date  \
# 158                                 Sokolov  64'; [14] 1962-06-03
# 327                                         Soler  24' 1982-06-16
# 607                         Şükür  1'; İlhan  13', 32' 2002-06-29
# 33                            Horvath  28'; Sesta  54' 1934-06-07
# 774                             Dempsey 1'; Brooks 86' 2014-06-16
# ..                                                 ...        ...
# 34                                            Puč  71' 1934-06-10
# 230               Schnellinger  90'; Müller  95', 110' 1970-06-17
# 358  Platini  26' (pen.); pen.  92'; Trésor  98'; G... 1982-07-08
# 658                                         Márquez 6' 2006-06-24
# 230               Schnellinger  90'; Müller  95', 110' 1970-06-17
#
#                Time                        Stadium         City  Attendance  \
# 158 0 days 15:00:00            Estadio El Teniente     Rancagua     74420.0
# 327 0 days 17:15:00                      San Mamés       Bilbao    441720.0
# 607 0 days 20:00:00        Daegu World Cup Stadium        Daegu    634830.0
# 33  0 days 18:00:00       Stadio Giorgio Ascarelli       Naples     70000.0
# 774 0 days 19:00:00                Arena das Dunas        Natal    397600.0
# ..              ...                            ...          ...         ...
# 34  0 days 15:30:00           Stadio Nazionale PNF         Rome    550000.0
# 230 0 days 16:00:00                 Estadio Azteca  Mexico City   1024440.0
# 358 0 days 21:00:00  Ramón Sánchez Pizjuán Stadium      Seville    700000.0
# 658 0 days 21:00:00                 Zentralstadion      Leipzig    430000.0
# 230 0 days 16:00:00                 Estadio Azteca  Mexico City   1024440.0
#
#                     Referee Referee_City  \
# 158  Juan Gardeazábal Garay        Spain
# 327         António Garrido     Portugal
# 607               Saad Mane       Kuwait
# 33           Albino Carraro        Italy
# 774          Jonas Eriksson       Sweden
# ..                      ...          ...
# 34              Ivan Eklind       Sweden
# 230         Arturo Yamasaki         Peru
# 358          Charles Corver  Netherlands
# 658         Massimo Busacca  Switzerland
# 230         Arturo Yamasaki         Peru
#
#                                           Players_Goal Player_Name Goal_Time
# 158  Albert  1', 6', 53'; Tichy  8', 70'; Solymosi ...      Albert         1
# 327            Robson  1', 67'; Mariner  83'Soler  24'      Robson         1
# 607  Lee Eul-yong  9'; Song Chong-gug  90+3'Şükür  ...       Şükür         1
# 33   Lehner  1', 42'; Conen  27'Horvath  28'; Sesta...      Lehner         1
# 774                  A. Ayew 82'Dempsey 1'; Brooks 86'     Dempsey         1
# ..                                                 ...         ...       ...
# 34                    Orsi  81'; Schiavio  95'Puč  71'    Schiavio        95
# 230  Boninsegna  8'; Burgnich  98'; Riva  104'; Riv...      Müller        95
# 358  Littbarski  17'; Rummenigge  102'; Fischer  10...      Trésor        98
# 658                Crespo 10'; Rodríguez 98'Márquez 6'   Rodríguez        98
# 230  Boninsegna  8'; Burgnich  98'; Riva  104'; Riv...    Burgnich        98
#
# [2032 rows x 16 columns]

# %%
fifa2 = expanded_fifa.copy()

# %%
fifa2.reset_index()
# Out:
#       index  Home_Team Score Away_Team  Penalties  \
# 0         0     france   4–1    Mexico          0
# 1         0     france   4–1    Mexico          0
# 2         0     france   4–1    Mexico          0
# 3         0     france   4–1    Mexico          0
# 4         1  argentina   1–0    France          0
# ...     ...        ...   ...       ...        ...
# 2027    864     france   4–2   Croatia          0
# 2028    864     france   4–2   Croatia          0
# 2029    864     france   4–2   Croatia          0
# 2030    864     france   4–2   Croatia          0
# 2031    864     france   4–2   Croatia          0
#
#                                        First_Team_Goals  \
# 0     L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1     L. Laurent  19'; Langiller  40'; Maschinot  43...
# 2     L. Laurent  19'; Langiller  40'; Maschinot  43...
# 3     L. Laurent  19'; Langiller  40'; Maschinot  43...
# 4                                            Monti  81'
# ...                                                 ...
# 2027  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2028  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2029  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2030  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2031  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
#
#                Second_Team_Goals       Date            Time  \
# 0                   Carreño  70' 1930-07-13 0 days 15:00:00
# 1                   Carreño  70' 1930-07-13 0 days 15:00:00
# 2                   Carreño  70' 1930-07-13 0 days 15:00:00
# 3                   Carreño  70' 1930-07-13 0 days 15:00:00
# 4                            NaN 1930-07-15 0 days 16:00:00
# ...                          ...        ...             ...
# 2027  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 2028  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 2029  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 2030  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
# 2031  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
#
#                      Stadium        City  Attendance        Referee  \
# 0            Estadio Pocitos  Montevideo     44440.0        Uruguay
# 1            Estadio Pocitos  Montevideo     44440.0        Uruguay
# 2            Estadio Pocitos  Montevideo     44440.0        Uruguay
# 3            Estadio Pocitos  Montevideo     44440.0        Uruguay
# 4     Estadio Parque Central  Montevideo    234090.0   Almeida Rêgo
# ...                      ...         ...         ...            ...
# 2027        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 2028        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 2029        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 2030        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
# 2031        Luzhniki Stadium      Moscow    780110.0  Néstor Pitana
#
#      Referee_City                                       Players_Goal  \
# 0             NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 1             NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 2             NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 3             NaN  L. Laurent  19'; Langiller  40'; Maschinot  43...
# 4          Brazil                                                NaN
# ...           ...                                                ...
# 2027    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2028    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2029    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2030    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
# 2031    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
#
#      Player_Name Goal_Time
# 0     L. Laurent        19
# 1      Langiller        40
# 2      Maschinot        43
# 3        Carreño        70
# 4          Monti        81
# ...          ...       ...
# 2027   Griezmann        38
# 2028       Pogba        59
# 2029      Mbappé        65
# 2030     Perišić        28
# 2031   Mandžukić        69
#
# [2032 rows x 17 columns]

# %%
fifa.tail()
# Out:
#     Home_Team         Score Away_Team  Penalties  \
# 860    russia  2–2 (a.e.t.)   Croatia          0
# 861    france           1–0   Belgium          0
# 862   croatia  2–1 (a.e.t.)   England          0
# 863   belgium           2–0   England          0
# 864    france           4–2   Croatia          0
#
#                                       First_Team_Goals  \
# 860                      Cheryshev 31'; Fernandes 115'
# 861                                         Umtiti 51'
# 862                        Perišić 68'; Mandžukić 109'
# 863                          Meunier 4'; E. Hazard 82'
# 864  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
#
#               Second_Team_Goals       Date            Time  \
# 860     Kramarić 39'; Vida 101' 2018-07-07 0 days 21:00:00
# 861                         NaN 2018-07-10 0 days 21:00:00
# 862                 Trippier 5' 2018-07-11 0 days 21:00:00
# 863                         NaN 2018-07-14 0 days 17:00:00
# 864  Perišić 28'; Mandžukić 69' 2018-07-15 0 days 18:00:00
#
#                    Stadium              City   Attendance          Referee  \
# 860  Fisht Olympic Stadium             Sochi  442872020.0     Sandro Ricci
# 861     Krestovsky Stadium  Saint Petersburg  642862030.0     Andrés Cunha
# 862       Luzhniki Stadium            Moscow  780112040.0     Cüneyt Çakır
# 863     Krestovsky Stadium  Saint Petersburg  644062050.0  Alireza Faghani
# 864       Luzhniki Stadium            Moscow     780110.0    Néstor Pitana
#
#     Referee_City                                       Players_Goal
# 860       Brazil  Cheryshev 31'; Fernandes 115'Kramarić 39'; Vid...
# 861      Uruguay                                                NaN
# 862       Turkey             Perišić 68'; Mandžukić 109'Trippier 5'
# 863         Iran                                                NaN
# 864    Argentina  Mandžukić 18' (o.g.); Griezmann 38' (pen.); Po...
