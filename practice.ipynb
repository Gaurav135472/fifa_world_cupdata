# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Fifa_world_cup_5.csv')

# %%
df.head()
# Out:
#    Home_Team Away_Team  Home_Score  Away_Score Penalties Player_Name  \
# 0     france    Mexico         4.0         1.0        NO  L. Laurent
# 1     france    Mexico         4.0         1.0        NO   Langiller
# 2     france    Mexico         4.0         1.0        NO   Maschinot
# 3     france    Mexico         4.0         1.0        NO     Carreño
# 4  argentina    France         1.0         0.0        NO       Monti
#
#    Goal_Time   Outcome        Date      Time                 Stadium  \
# 0         19  Home Win  1930-07-13  15:00:00         Estadio Pocitos
# 1         40  Home Win  1930-07-13  15:00:00         Estadio Pocitos
# 2         43  Home Win  1930-07-13  15:00:00         Estadio Pocitos
# 3         70  Home Win  1930-07-13  15:00:00         Estadio Pocitos
# 4         81  Home Win  1930-07-15  16:00:00  Estadio Parque Central
#
#          City  Attendance       Referee Referee_City  Hour
# 0  Montevideo     44440.0       unknown      Uruguay  15.0
# ...

# %%
fifa = pd.read_csv('player_info.csv')

# %%
fifa[fifa['Name'] == 'Loïc Feudjou']
# Out:
#       Year          Name Position                        Date of Birth Caps  \
# 8684  2014  Loïc Feudjou      1GK  (1992-04-14)14 April 1992 (aged 22)    2
#
#              Club
# 8684  Coton Sport

# %%
df = pd.read_csv('all_player_info.csv')

# %%
df[df['current_team'] == 'Inter Miami']
# Out:
#                       Player name                                       DOB  \
# 1856  Luis Alberto Suárez Díaz[1]  (1987-01-24) 24 January 1987 (age 37)[1]
# 5867       Lionel Andrés Messi[1]     (1987-06-24) 24 June 1987 (age 37)[1]
# 6773    Sergio Busquets Burgos[1]     (1988-07-16) 16 July 1988 (age 36)[1]
# 6898          Jordi Alba Ramos[1]    (1989-03-21) 21 March 1989 (age 35)[2]
#
#                            birth_place                 height  \
# 1856                    Salto, Uruguay  1.82 m (6 ft 0 in)[1]
# 5867                Rosario, Argentina  1.70 m (5 ft 7 in)[1]
# 6773                   Sabadell, Spain  1.89 m (6 ft 2 in)[1]
# 6898  L'Hospitalet de Llobregat, Spain  1.70 m (5 ft 7 in)[3]
#
#                   position current_team number  \
# 1856               Striker  Inter Miami      9
# 5867               Forward  Inter Miami     10
# 6773  Defensive midfielder  Inter Miami      5
# 6898             Left-back  Inter Miami     18
#
# ...
